# %%
# %run image_detect.py --image_folder data/custom/images/ --weights_path checkpoints/yolov3_ckpt_9.pth
# Out:
# Namespace(batch_size=1, checkpoint_model=None, class_path='data/custom/classes.names', conf_thres=0.9, image_folder='data/custom/images/', img_size=480, model_def='config/yolov3_custom.cfg', n_cpu=1, nms_thres=0.01, weights_path='checkpoints/yolov3_ckpt_9.pth')
# ['usb', 'charge', 'done', 'batt+', 'batt-', 'rprog']
#
# Performing object detection:
# [tensor([[4.0213e+02, 3.4230e+02, 4.3963e+02, 3.8479e+02, 9.8017e-01, 9.1295e-01,
#          4.0000e+00],
#         [3.9279e+02, 1.0561e+02, 4.2995e+02, 1.4475e+02, 9.5199e-01, 9.2433e-01,
#          3.0000e+00],
#         [3.4582e+02, 1.1011e+02, 3.7431e+02, 1.6177e+02, 9.0217e-01, 4.3705e-01,
#          1.0000e+00]])]
# 	+ Batch 0, Inference Time: 0:00:04.350913
# [tensor([[ 41.4519, 164.5400, 204.5919, 303.0537,   0.9548,   0.9962,   0.0000],
#         [403.2577, 341.7525, 440.9771, 385.2917,   0.9793,   0.8905,   4.0000],
#         [392.8216, 106.0497, 428.8514, 145.1549,   0.9632,   0.8779,   3.0000],
# ...

# %%
# %run video_detect.py
# Out:
# ['usb', 'charge', 'done', 'batt+', 'batt-', 'rprog']
# Video size: (1280, 720)
# tensor([[252.3639, 190.9290, 281.2309, 227.5358,   0.9835,   0.7316,   2.0000],
#         [284.5064, 187.6319, 314.0185, 228.6894,   0.9960,   0.7078,   2.0000],
#         [269.3876, 181.9185, 297.2113, 224.3107,   0.7001,   0.8806,   2.0000],
#         [294.5092, 179.2621, 322.5999, 223.5860,   0.5282,   0.8866,   2.0000]])
# tensor([[256.6866, 194.7807, 286.1571, 231.5332,   0.8620,   0.9241,   2.0000],
#         [284.2612, 189.1448, 313.7803, 231.0499,   0.9084,   0.7592,   2.0000],
#         [271.1587, 181.2722, 299.8560, 228.0004,   0.7232,   0.9516,   2.0000],
#         [266.4974, 176.2658, 300.3022, 217.3016,   0.7192,   0.5565,   1.0000]])
# tensor([[258.0751, 194.7185, 286.7205, 231.6824,   0.7625,   0.9533,   2.0000],
#         [278.2849, 180.8347, 308.3024, 227.7631,   0.7569,   0.9516,   2.0000],
#         [284.0978, 197.0945, 312.6932, 232.6035,   0.9998,   0.4627,   1.0000],
# ...

# %%
# %run test.py
# Out:
# Namespace(batch_size=1, class_path='data/custom.names', conf_thres=0.1, data_config='config/custom.data', img_size=480, iou_thres=0.3, model_def='config/yolov3_custom.cfg', n_cpu=1, nms_thres=0.3, weights_path='checkpoints/yolov3_ckpt_9.pth')
# Compute mAP...
# ...
# Computing AP: 100%|████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1499.13it/s]
# Average Precisions:
# + Class '0' (usb) - AP: 0.8
# + Class '1' (charge) - AP: 0.9694950517318939
# + Class '2' (done) - AP: 0.18333333333333335
# + Class '3' (batt+) - AP: 1.091880341880342
# + Class '4' (batt-) - AP: 0.9769230769230769
# + Class '5' (rprog) - AP: 0.9506535947712418
# mAP: 0.828714233106648
